# %% [markdown]
# <a href="https://colab.research.google.com/github/Mootha-sri-harshit/OpenCv_/blob/main/EdgeDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Edge Detection Using Canny Edge Detection'''

import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('download.jpg',0)
edges = cv.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
echo "# opencv" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Mootha-sri-harshit/opencv.git
git push -u origin main
# Out:
#   File "<ipython-input-3-0186770279b5>", line 1
#     echo "# opencv" >> README.md
#          ^
# SyntaxError: invalid syntax
